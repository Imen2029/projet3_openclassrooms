# %% [markdown]
# * [Analyse univariée](#au)
# * [Analyse bivariée](#ab)
# * [Analyse multivariée](#am)

# %%
import pandas as pd #(Vaex – Faster Pandas Alternate in Python)
import numpy as np
from hurry.filesize import size
import missingno as msno
import matplotlib.pyplot as plt 
import seaborn as sns
plt.style.use('seaborn')
from sklearn.impute import KNNImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('data_exploration.csv',sep='\t')

# %%
df.columns
# Out:
# Index(['code', 'pnns_groups_1', 'pnns_groups_2', 'energy_100g', 'fat_100g',
#        'saturated-fat_100g', 'sugars_100g', 'fiber_100g', 'proteins_100g',
#        'sodium_100g', 'fruits-vegetables-nuts_100g', 'additives_n'],
#       dtype='object')

# %% [markdown]
# # Analyse univariée <a class="anchor" id="au"></a>
# ## Données catégorielles

# %%
df.describe()
# Out:
#         energy_100g      fat_100g  saturated-fat_100g   sugars_100g  \
# count  72794.000000  72794.000000        72794.000000  43032.000000
# mean    1060.045629     12.617301            4.897441     12.479824
# std      631.412851     13.287761            6.041509     17.077803
# min        0.000000     -5.522838           -1.623042      0.000000
# 25%      610.000000      3.000000            0.900000      1.000000
# 50%     1060.045629     12.617301            4.897441      4.000000
# 75%     1272.000000     12.617301            4.897441     17.225000
# max     4436.531519    100.000000          100.000000     96.000000
#
#          fiber_100g  proteins_100g   sodium_100g  fruits-vegetables-nuts_100g  \
# count  27748.000000   45875.000000  43206.000000                  2232.000000
# mean       2.298535       7.224221      0.282178                    34.020596
# std        2.491719       6.801783      0.308531                    31.270108
# ...

# %%
myFig=plt.figure(figsize=(20,10))
sns.countplot(df['pnns_groups_1'])
# Out:
# <AxesSubplot:xlabel='pnns_groups_1', ylabel='count'>

# %%
df['pnns_groups_1'].value_counts().plot(kind='pie',autopct='%.2f')
plt.show()

# %%
myFig=plt.figure(figsize=(25,15))
#sns.set(rc={'figure.figsize':(25,10)})
sns.countplot(df['pnns_groups_2'])
# Out:
# <AxesSubplot:xlabel='pnns_groups_2', ylabel='count'>

# %%
df['pnns_groups_2'].value_counts().plot(kind='pie',autopct='%.2f')
plt.show()

# %% [markdown]
# ## Données numériques

# %% [markdown]
# # Analyse bivariée <a class="anchor" id="ab"></a>

# %% [markdown]
# # Analyse multivariée <a class="anchor" id="am"></a>
